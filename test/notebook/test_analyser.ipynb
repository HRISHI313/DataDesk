# %%
import sys
sys.path.append(r"C:\Users\Lenovo\OneDrive - Retailstat, LLC\Documents\DataDesk")
import pandas as pd
from config import *

# %%
df = pd.read_excel(r"C:\Users\Lenovo\OneDrive - Retailstat, LLC\Documents\DataDesk\test\Sample\Grocery_Task_sample.xlsx")

# %%
df.head()
# Out:
#   Category  List ID     List Name             ALI  Polygon Status  \
# 0  grocery        9  Acme Markets  9242557-000000             NaN
# 1  grocery        9  Acme Markets  9242561-000000             NaN
# 2  grocery        9  Acme Markets  9242571-000000             NaN
# 3  grocery        9  Acme Markets  9242573-000000             NaN
# 4  grocery        9  Acme Markets  9242640-000000             NaN
#
#      Store Name                     Address           City State    ZIP  ...  \
# 0  Acme Markets            180 W Girard Ave   Philadelphia    PA  19123  ...
# 1  Acme Markets               1001 South St   Philadelphia    PA  19147  ...
# 2  Acme Markets  19-21 Ave At Port Imperial  West New York    NJ   7093  ...
# 3  Acme Markets               510 Valley Rd      Montclair    NJ   7043  ...
# 4  Acme Markets              4001 Walnut St   Philadelphia    PA  19104  ...
#
#     Latitude  Longitude           Parent ALI    Parent Store Name  \
# 0  39.969202 -75.139241    8430000003-000000   Shops at Schmidt's
# 1  39.942987 -75.158792                  NaN                  NaN
# 2  40.782118 -74.006760                  NaN                  NaN
# 3  40.837249 -74.207844  13105000-1200010140  510-516 Valley Road
# 4  39.954554 -75.202901                  NaN                  NaN
#
#         Parent List Name  HideTraffic  HideFromApp  LastUpdated  \
# 0  Sterling Organization          1.0          0.0   2026-02-01
# 1                    NaN          1.0          0.0   2026-02-01
# 2                    NaN          1.0          0.0   2026-02-01
# 3             Properties          NaN          0.0   2026-02-01
# 4                    NaN          1.0          0.0   2026-02-01
#
#    hideTrafficFor constructionFlag
# 0        manual,       Multi-Level
# 1        manual,       Multi-Level
# 2        manual,       Multi-Level
# 3             NaN      Multi-Level
# 4        manual,       Multi-Level
#
# [5 rows x 27 columns]

# %%
def total_record(dataframe):
    return len(dataframe)

total_record(df)
# Out:
# 534

# %%
def total_unique_retailers(dataframe):
    return dataframe[LIST_NAME_COL].unique()

total_unique_retailers(df)
# Out:
# <ArrowStringArray>
# [                 'Acme Markets',                    'Albertsons',
#  'Andronico's Community Markets',                    'Balducci's',
#                    'City Market',        'Costco Wholesale Corp.',
#           'Dillons Supermarkets',                   'Food 4 Less',
#                      'Food Lion',                    'Fred Meyer',
#       'Fry's Food & Drug Stores',                    'Giant Food',
#              'Giant Food Stores',         'Giant Heirloom Market',
#         'Hannaford Supermarkets',                 'Harris Teeter',
#                         'Hy-Vee',                    'Jewel-Osco',
#                   'King Soopers',                        'Kroger',
#                        'Lidl US',                     'Mariano's',
#                  'Market Street',                     'Pavilions',
#                   'Pick 'n Save',          'Publix Super Markets',
#     'QFC (Quality Food Centers)',                        'Ralphs',
#                        'Safeway',                  'Safeway Fuel',
#     'Smith's Food & Drug Stores',                   'Star Market',
#                    'Stop & Shop',     'Tom Thumb Food & Pharmacy',
#                   'Trader Joe's',            'Whole Foods Market']
# Length: 36, dtype: str

# %%
def total_unique_retailers_count(dataframe):
    return dataframe[LIST_NAME_COL].nunique()

total_unique_retailers_count(df)
# Out:
# 36

# %%
def records_per_retailer(dataframe):
    return dataframe[LIST_NAME_COL].value_counts()

records_per_retailer(df)
# Out:
# List Name
# Trader Joe's                     132
# Whole Foods Market               111
# Publix Super Markets              50
# Food Lion                         26
# Safeway                           25
# Costco Wholesale Corp.            24
# Lidl US                           21
# Kroger                            20
# Harris Teeter                     14
# Giant Food                        11
# Dillons Supermarkets               9
# Hy-Vee                             9
# Giant Food Stores                  7
# Hannaford Supermarkets             7
# Stop & Shop                        7
# QFC (Quality Food Centers)         6
# Ralphs                             6
# Star Market                        6
# Acme Markets                       5
# King Soopers                       4
# Mariano's                          4
# Market Street                      4
# Tom Thumb Food & Pharmacy          4
# Fry's Food & Drug Stores           3
# Giant Heirloom Market              3
# Jewel-Osco                         3
# Balducci's                         2
# Fred Meyer                         2
# Smith's Food & Drug Stores         2
# Albertsons                         1
# Andronico's Community Markets      1
# City Market                        1
# Food 4 Less                        1
# Pavilions                          1
# Pick 'n Save                       1
# Safeway Fuel                       1
# Name: count, dtype: int64
